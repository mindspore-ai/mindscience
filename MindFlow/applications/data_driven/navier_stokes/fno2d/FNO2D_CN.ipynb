# %% [markdown]
# # 基于Fourier Neural Operator的Navier-Stokes equation求解
#
# [![下载Notebook](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_notebook.png)](https://obs.dualstack.cn-north-4.myhuaweicloud.com/mindspore-website/notebook/master/mindflow/zh_cn/data_driven/mindspore_navier_stokes_FNO2D.ipynb)&emsp;[![下载样例代码](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_download_code.png)](https://obs.dualstack.cn-north-4.myhuaweicloud.com/mindspore-website/notebook/master/mindflow/zh_cn/data_driven/mindspore_navier_stokes_FNO2D.py)&emsp;[![查看源文件](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_source.png)](https://gitee.com/mindspore/docs/blob/master/docs/mindflow/docs/source_zh_cn/data_driven/navier_stokes_FNO2D.ipynb)

# %% [markdown]
# ## 概述
#
# 计算流体力学是21世纪流体力学领域的重要技术之一，其通过使用数值方法在计算机中对流体力学的控制方程进行求解，从而实现流动的分析、预测和控制。传统的有限元法（finite element method，FEM）和有限差分法（finite difference method，FDM）常用于复杂的仿真流程（物理建模、网格划分、数值离散、迭代求解等）和较高的计算成本，往往效率低下。因此，借助AI提升流体仿真效率是十分必要的。
#
# 近年来，随着神经网络的迅猛发展，为科学计算提供了新的范式。经典的神经网络是在有限维度的空间进行映射，只能学习与特定离散化相关的解。与经典神经网络不同，傅里叶神经算子（Fourier Neural Operator，FNO）是一种能够学习无限维函数空间映射的新型深度学习架构。该架构可直接学习从任意函数参数到解的映射，用于解决一类偏微分方程的求解问题，具有更强的泛化能力。更多信息可参考[Fourier Neural Operator for Parametric Partial Differential Equations](https://arxiv.org/abs/2010.08895)。
#
# 本案例教程介绍利用傅里叶神经算子的纳维-斯托克斯方程（Navier-Stokes equation）求解方法。

# %% [markdown]
# ## 纳维-斯托克斯方程（Navier-Stokes equation）
#
# 纳维-斯托克斯方程（Navier-Stokes equation）是计算流体力学领域的经典方程，是一组描述流体动量守恒的偏微分方程，简称N-S方程。它在二维不可压缩流动中的涡度形式如下：
#
# $$
# \partial_t w(x, t)+u(x, t) \cdot \nabla w(x, t)=\nu \Delta w(x, t)+f(x), \quad x \in(0,1)^2, t \in(0, T]
# $$
#
# $$
# \nabla \cdot u(x, t)=0, \quad x \in(0,1)^2, t \in[0, T]
# $$
#
# $$
# w(x, 0)=w_0(x), \quad x \in(0,1)^2
# $$
#
# 其中$u$表示速度场，$w=\nabla \times u$表示涡度，$w_0(x)$表示初始条件，$\nu$表示粘度系数，$f(x)$为外力合力项。

# %% [markdown]
# ## 问题描述
#
# 本案例利用Fourier Neural Operator学习某一个时刻对应涡度到下一时刻涡度的映射，实现二维不可压缩N-S方程的求解：
#
# $$
# w_t \mapsto w(\cdot, t+1)
# $$

# %% [markdown]
# ## 技术路径
#
# MindFlow求解该问题的具体流程如下：
#
# 1. 创建数据集。
# 2. 构建模型。
# 3. 优化器与损失函数。
# 4. 模型训练。

# %% [markdown]
# ## Fourier Neural Operator
#
# Fourier Neural Operator模型构架如下图所示。图中$w_0(x)$表示初始涡度，通过Lifting Layer实现输入向量的高维映射，然后将映射结果作为Fourier Layer的输入，进行频域信息的非线性变换，最后由Decoding Layer将变换结果映射至最终的预测结果$w_1(x)$。
#
# Lifting Layer、Fourier Layer以及Decoding Layer共同组成了Fourier Neural Operator。
#
# ![Fourier Neural Operator模型构架](images/FNO.png)
#
# Fourier Layer网络结构如下图所示。图中V表示输入向量，上框表示向量经过傅里叶变换后，经过线性变换R，过滤高频信息，然后进行傅里叶逆变换；另一分支经过线性变换W，最后通过激活函数，得到Fourier Layer输出向量。
#
# ![Fourier Layer网络结构](images/FNO-2.png)

# %%
import sys
import os
project_root = os.path.abspath("../../../../..")
sys.path.append(project_root)

# %%
import os
import time
import numpy as np

import mindspore
import mindspore.common.dtype as mstype
from mindspore import nn, context, ops, Tensor, jit, set_seed, save_checkpoint
from IPython.display import Image, display
# Out:
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %% [markdown]
# 下述`src`包可以在[applications/data_driven/navier_stokes/fno2d/src](https://gitee.com/mindspore/mindscience/tree/master/MindFlow/applications/data_driven/navier_stokes/fno2d/src)下载。

# %%
from mindscience.models import FNO2D
from mindscience.common import get_warmup_cosine_annealing_lr
from mindscience.common import RelativeRMSELoss
from mindscience.utils import load_yaml_config
from mindscience.pde import UnsteadyFlowWithLoss
from src import calculate_l2_error, create_training_dataset, visual

set_seed(0)
np.random.seed(0)

# %%
# set context for training: using graph mode for high performance training with GPU acceleration
context.set_context(mode=context.GRAPH_MODE, device_target='Ascend', device_id=0,max_device_memory="32GB")
use_ascend = context.get_context(attr_key='device_target') == "Ascend"
config = load_yaml_config('./configs/fno2d.yaml')
data_params = config["data"]
model_params = config["model"]
optimizer_params = config["optimizer"]
summary_params = config["summary"]

# %% [markdown]
# ## 创建数据集
#
# 训练与测试数据下载: [data_driven/navier_stokes/dataset](https://download.mindspore.cn/mindscience/mindflow/dataset/applications/data_driven/navier_stokes/dataset/) .
#
# 本案例根据Zongyi Li在 [Fourier Neural Operator for Parametric Partial Differential Equations](https://arxiv.org/pdf/2010.08895.pdf) 一文中对数据集的设置生成训练数据集与测试数据集。具体设置如下：
#
# 基于周期性边界，生成满足如下分布的初始条件$w_0(x)$：
#
# $$
# w_0 \sim \mu, \mu=\mathcal{N}\left(0,7^{3 / 2}(-\Delta+49 I)^{-2.5}\right)
# $$
#
# 外力项设置为：
#
# $$
# f(x)=0.1\left(\sin \left(2 \pi\left(x_1+x_2\right)\right)+\right.\cos(2 \pi(x_1+x_2)))
# $$
#
# 采用`Crank-Nicolson`方法生成数据，时间步长设置为1e-4，最终数据以每 t = 1 个时间单位记录解。所有数据均在256×256的网格上生成，并被下采样至64×64网格。本案例选取粘度系数$\nu=1e−5$，训练集样本量为19000个，测试集样本量为3800个。

# %%
train_dataset = create_training_dataset(data_params, input_resolution=model_params["input_resolution"], shuffle=True)
test_input = np.load(os.path.join(data_params["root_dir"], "test/inputs.npy"))
test_label = np.load(os.path.join(data_params["root_dir"], "test/label.npy"))

data_path = data_params['root_dir']

resolution = data_params['resolution']
batch_size = data_params['batch_size']
n_batches = data_params['test_size'] // batch_size
data_shape = (n_batches, batch_size, resolution, resolution)
labels_unif = np.load(os.path.join(data_path, "test/label.npy")).reshape(data_shape)
# Out:
# Data preparation finished

# %% [markdown]
# ## 构建模型
#
# 网络由1层Lifting layer、多层Fourier Layer以及1层Decoding layer叠加组成：
#
# - Lifting layer对应样例代码中`FNO2D.fc0`，将输出数据$x$映射至高维；
#
# - 多层Fourier Layer的叠加对应样例代码中`FNO2D.fno_seq`，本案例采用离散傅里叶变换实现时域与频域的转换；
#
# - Decoding layer对应代码中`FNO2D.fc1`与`FNO2D.fc2`，获得最终的预测值。

# %%
if use_ascend:
    compute_type = mstype.float16
else:
    compute_type = mstype.float32
# prepare model
model = FNO2D(in_channels=model_params["in_channels"],
              out_channels=model_params["out_channels"],
              n_modes=[model_params["modes"], model_params["modes"]],
              resolutions=[model_params["input_resolution"], model_params["input_resolution"]],
              hidden_channels=model_params["width"],
              n_layers=model_params["depth"],
              projection_channels=4*model_params["width"],
              fno_compute_dtype=compute_type)

model_params_list = []
for k, v in model_params.items():
    model_params_list.append(f"{k}-{v}")
model_name = "_".join(model_params_list)

# %% [markdown]
# ## 优化器与损失函数
#
# 使用相对均方根误差作为网络训练损失函数：

# %%
steps_per_epoch = train_dataset.get_dataset_size()
lr = get_warmup_cosine_annealing_lr(lr_init=optimizer_params["learning_rate"],
                                    last_epoch=optimizer_params["epochs"],
                                    steps_per_epoch=steps_per_epoch,
                                    warmup_epochs=optimizer_params["warmup_epochs"])

optimizer = nn.AdamWeightDecay(model.trainable_params(), learning_rate=Tensor(lr),
                               weight_decay=optimizer_params['weight_decay'])

problem = UnsteadyFlowWithLoss(model, loss_fn=RelativeRMSELoss(), data_format="NHWTC")

if use_ascend:
    from mindspore.amp import DynamicLossScaler, auto_mixed_precision, all_finite
    loss_scaler = DynamicLossScaler(1024, 2, 100)
    auto_mixed_precision(model, "O3")
else:
    loss_scaler = None

# %% [markdown]
# ## 模型训练
#
# 使用**MindSpore >= 2.0.0**的版本，可以使用函数式编程范式训练神经网络。

# %%
def train():
    def forward_fn(train_inputs, train_label):
        loss = problem.get_loss(train_inputs, train_label)
        if use_ascend:
            loss = loss_scaler.scale(loss)
        return loss

    grad_fn = ops.value_and_grad(forward_fn, None, optimizer.parameters, has_aux=False)

    @jit
    def train_step(train_inputs, train_label):
        loss, grads = grad_fn(train_inputs, train_label)
        if use_ascend:
            loss = loss_scaler.unscale(loss)
            is_finite = all_finite(grads)
            if is_finite:
                grads = loss_scaler.unscale(grads)
                loss = ops.depend(loss, optimizer(grads))
            loss_scaler.adjust(is_finite)
        else:
            loss = ops.depend(loss, optimizer(grads))
        return loss

    sink_process = mindspore.data_sink(train_step, train_dataset, sink_size=1)
    summary_dir = os.path.join(summary_params["root_dir"], model_name)
    ckpt_dir = os.path.join(summary_dir, "ckpt")
    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)

    for epoch in range(1, 1+optimizer_params["epochs"]):
        local_time_beg = time.time()
        model.set_train(True)
        for _ in range(steps_per_epoch):
            cur_loss = sink_process()
        print(
            f"epoch: {epoch} train loss: {cur_loss.asnumpy():.8f}"\
            f" epoch time: {time.time() - local_time_beg:.2f}s"\
            f" step time: {(time.time() - local_time_beg)/steps_per_epoch:.4f}s")

        model.set_train(False)
        if epoch % summary_params["save_ckpt_interval"] == 0:
            save_checkpoint(model, os.path.join(ckpt_dir, model_params["name"]))

        if epoch % summary_params['test_interval'] == 0:
            calculate_l2_error(model, test_input, test_label, summary_params["test_batch_size"])

# %%
train()
# Out:
# [ERROR] CORE(451,ffffa496a020,python):2025-11-30-04:04:15.270.337 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_451/3026266978.py]
# [ERROR] CORE(451,ffffa496a020,python):2025-11-30-04:04:15.270.453 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_451/3026266978.py]
# [ERROR] CORE(451,ffffa496a020,python):2025-11-30-04:04:15.270.713 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_451/3026266978.py]
# [ERROR] CORE(451,ffffa496a020,python):2025-11-30-04:04:15.270.765 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_451/3026266978.py]
# ........epoch: 1 train loss: 1.30843186 epoch time: 115.17s step time: 0.1152s
# epoch: 2 train loss: 1.53351986 epoch time: 32.97s step time: 0.0330s
# epoch: 3 train loss: 1.06035268 epoch time: 32.79s step time: 0.0328s
# epoch: 4 train loss: 1.42428875 epoch time: 32.35s step time: 0.0324s
# epoch: 5 train loss: 1.12775147 epoch time: 32.94s step time: 0.0329s
# epoch: 6 train loss: 0.99399227 epoch time: 32.74s step time: 0.0327s
# epoch: 7 train loss: 1.18743980 epoch time: 32.81s step time: 0.0328s
# epoch: 8 train loss: 0.96227854 epoch time: 33.24s step time: 0.0332s
# epoch: 9 train loss: 0.97122145 epoch time: 33.00s step time: 0.0330s
# epoch: 10 train loss: 1.00732780 epoch time: 33.59s step time: 0.0336s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.10409218325279652
# =================================End Evaluation=================================
# predict total time: 24.895456075668335 s
# epoch: 11 train loss: 0.77905238 epoch time: 32.76s step time: 0.0328s
# epoch: 12 train loss: 0.69114518 epoch time: 33.29s step time: 0.0333s
# epoch: 13 train loss: 0.88763446 epoch time: 32.55s step time: 0.0326s
# epoch: 14 train loss: 0.73742425 epoch time: 33.01s step time: 0.0330s
# epoch: 15 train loss: 0.82787764 epoch time: 32.50s step time: 0.0325s
# epoch: 16 train loss: 0.76049018 epoch time: 32.85s step time: 0.0329s
# epoch: 17 train loss: 0.56922662 epoch time: 32.71s step time: 0.0327s
# epoch: 18 train loss: 0.65339023 epoch time: 32.54s step time: 0.0325s
# epoch: 19 train loss: 1.03959846 epoch time: 32.56s step time: 0.0326s
# epoch: 20 train loss: 0.87571859 epoch time: 32.65s step time: 0.0326s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.09700032213516534
# =================================End Evaluation=================================
# predict total time: 20.460766553878784 s
# epoch: 21 train loss: 0.84693062 epoch time: 32.86s step time: 0.0329s
# epoch: 22 train loss: 0.90492022 epoch time: 33.99s step time: 0.0340s
# epoch: 23 train loss: 0.87100005 epoch time: 32.96s step time: 0.0330s
# epoch: 24 train loss: 0.91224092 epoch time: 33.53s step time: 0.0335s
# epoch: 25 train loss: 0.89035714 epoch time: 32.31s step time: 0.0323s
# epoch: 26 train loss: 0.58009017 epoch time: 32.41s step time: 0.0324s
# epoch: 27 train loss: 0.53826815 epoch time: 32.26s step time: 0.0323s
# epoch: 28 train loss: 0.98347741 epoch time: 32.77s step time: 0.0328s
# epoch: 29 train loss: 0.68444407 epoch time: 31.87s step time: 0.0319s
# epoch: 30 train loss: 0.79781973 epoch time: 31.64s step time: 0.0316s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.10056259689945728
# =================================End Evaluation=================================
# predict total time: 18.296407461166382 s
# epoch: 31 train loss: 0.81010062 epoch time: 30.93s step time: 0.0309s
# epoch: 32 train loss: 0.62860209 epoch time: 30.56s step time: 0.0306s
# epoch: 33 train loss: 0.83840472 epoch time: 30.56s step time: 0.0306s
# epoch: 34 train loss: 0.67510211 epoch time: 31.22s step time: 0.0312s
# epoch: 35 train loss: 0.80056667 epoch time: 30.91s step time: 0.0309s
# epoch: 36 train loss: 0.76824903 epoch time: 31.01s step time: 0.0310s
# epoch: 37 train loss: 0.89015108 epoch time: 30.98s step time: 0.0310s
# epoch: 38 train loss: 0.70030224 epoch time: 30.97s step time: 0.0310s
# epoch: 39 train loss: 1.05957937 epoch time: 31.49s step time: 0.0315s
# epoch: 40 train loss: 0.91465116 epoch time: 30.87s step time: 0.0309s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.09345954347681254
# =================================End Evaluation=================================
# predict total time: 18.151524782180786 s
# epoch: 41 train loss: 0.60066813 epoch time: 30.67s step time: 0.0307s
# epoch: 42 train loss: 0.61000919 epoch time: 30.51s step time: 0.0305s
# epoch: 43 train loss: 0.64219582 epoch time: 30.66s step time: 0.0307s
# epoch: 44 train loss: 0.67425144 epoch time: 30.75s step time: 0.0308s
# epoch: 45 train loss: 0.66691154 epoch time: 31.06s step time: 0.0311s
# epoch: 46 train loss: 1.18046880 epoch time: 30.90s step time: 0.0309s
# epoch: 47 train loss: 0.56656659 epoch time: 30.80s step time: 0.0308s
# epoch: 48 train loss: 0.94008696 epoch time: 31.10s step time: 0.0311s
# epoch: 49 train loss: 0.82543069 epoch time: 31.15s step time: 0.0311s
# epoch: 50 train loss: 0.55465096 epoch time: 30.71s step time: 0.0307s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.10578877762891352
# =================================End Evaluation=================================
# predict total time: 18.166221380233765 s
# epoch: 51 train loss: 0.73558575 epoch time: 30.79s step time: 0.0308s
# epoch: 52 train loss: 0.74642181 epoch time: 31.30s step time: 0.0313s
# epoch: 53 train loss: 0.66942996 epoch time: 31.47s step time: 0.0315s
# epoch: 54 train loss: 0.87896222 epoch time: 31.34s step time: 0.0313s
# epoch: 55 train loss: 0.91395187 epoch time: 30.87s step time: 0.0309s
# epoch: 56 train loss: 0.54529727 epoch time: 30.79s step time: 0.0308s
# epoch: 57 train loss: 0.77168405 epoch time: 30.55s step time: 0.0306s
# epoch: 58 train loss: 0.69679034 epoch time: 30.66s step time: 0.0307s
# epoch: 59 train loss: 0.76235938 epoch time: 30.67s step time: 0.0307s
# epoch: 60 train loss: 0.73032451 epoch time: 30.78s step time: 0.0308s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.07257222954090685
# =================================End Evaluation=================================
# predict total time: 18.51615810394287 s
# epoch: 61 train loss: 0.77750158 epoch time: 31.22s step time: 0.0312s
# epoch: 62 train loss: 0.59837765 epoch time: 30.76s step time: 0.0308s
# epoch: 63 train loss: 0.52746183 epoch time: 30.51s step time: 0.0305s
# epoch: 64 train loss: 0.59964222 epoch time: 30.91s step time: 0.0309s
# epoch: 65 train loss: 0.59929836 epoch time: 30.51s step time: 0.0305s
# epoch: 66 train loss: 0.55541557 epoch time: 30.26s step time: 0.0303s
# epoch: 67 train loss: 0.96813172 epoch time: 30.67s step time: 0.0307s
# epoch: 68 train loss: 0.75970656 epoch time: 30.85s step time: 0.0308s
# epoch: 69 train loss: 0.54088628 epoch time: 31.12s step time: 0.0311s
# epoch: 70 train loss: 0.65591043 epoch time: 30.77s step time: 0.0308s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.07677798835746943
# =================================End Evaluation=================================
# predict total time: 18.8860445022583 s
# epoch: 71 train loss: 0.67122155 epoch time: 30.63s step time: 0.0306s
# epoch: 72 train loss: 0.62457943 epoch time: 31.02s step time: 0.0310s
# epoch: 73 train loss: 0.73655242 epoch time: 30.80s step time: 0.0308s
# epoch: 74 train loss: 0.49366343 epoch time: 30.80s step time: 0.0308s
# epoch: 75 train loss: 0.63750291 epoch time: 30.73s step time: 0.0307s
# epoch: 76 train loss: 0.65376270 epoch time: 30.82s step time: 0.0308s
# epoch: 77 train loss: 0.77738094 epoch time: 30.71s step time: 0.0307s
# epoch: 78 train loss: 0.63001668 epoch time: 30.90s step time: 0.0309s
# epoch: 79 train loss: 0.67289704 epoch time: 31.58s step time: 0.0316s
# epoch: 80 train loss: 0.61163056 epoch time: 30.97s step time: 0.0310s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.07443147992994636
# =================================End Evaluation=================================
# predict total time: 17.869483947753906 s
# epoch: 81 train loss: 0.97286260 epoch time: 30.63s step time: 0.0306s
# epoch: 82 train loss: 0.51350302 epoch time: 30.43s step time: 0.0304s
# epoch: 83 train loss: 0.70488638 epoch time: 30.43s step time: 0.0304s
# epoch: 84 train loss: 0.69630349 epoch time: 30.53s step time: 0.0305s
# epoch: 85 train loss: 0.65173876 epoch time: 31.02s step time: 0.0310s
# epoch: 86 train loss: 0.51755106 epoch time: 31.25s step time: 0.0312s
# epoch: 87 train loss: 0.55027056 epoch time: 31.56s step time: 0.0316s
# epoch: 88 train loss: 0.73609108 epoch time: 30.71s step time: 0.0307s
# epoch: 89 train loss: 0.68281054 epoch time: 31.11s step time: 0.0311s
# epoch: 90 train loss: 0.60824060 epoch time: 31.01s step time: 0.0310s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.06816967201791704
# =================================End Evaluation=================================
# predict total time: 18.069430351257324 s
# epoch: 91 train loss: 0.61844248 epoch time: 30.60s step time: 0.0306s
# epoch: 92 train loss: 0.53925419 epoch time: 30.54s step time: 0.0305s
# epoch: 93 train loss: 0.71054441 epoch time: 30.48s step time: 0.0305s
# epoch: 94 train loss: 0.55362958 epoch time: 30.58s step time: 0.0306s
# epoch: 95 train loss: 0.97625571 epoch time: 30.69s step time: 0.0307s
# epoch: 96 train loss: 0.56779897 epoch time: 30.28s step time: 0.0303s
# epoch: 97 train loss: 0.46870828 epoch time: 30.59s step time: 0.0306s
# epoch: 98 train loss: 0.55128586 epoch time: 30.62s step time: 0.0306s
# epoch: 99 train loss: 0.61473167 epoch time: 30.71s step time: 0.0307s
# epoch: 100 train loss: 0.63115984 epoch time: 30.49s step time: 0.0305s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.06642470365483313
# =================================End Evaluation=================================
# predict total time: 18.094850301742554 s
# epoch: 101 train loss: 0.52221388 epoch time: 30.66s step time: 0.0307s
# epoch: 102 train loss: 0.70059288 epoch time: 30.35s step time: 0.0304s
# epoch: 103 train loss: 0.87859666 epoch time: 30.39s step time: 0.0304s
# epoch: 104 train loss: 0.68385422 epoch time: 30.68s step time: 0.0307s
# epoch: 105 train loss: 0.61408401 epoch time: 30.44s step time: 0.0304s
# epoch: 106 train loss: 0.58210313 epoch time: 30.46s step time: 0.0305s
# epoch: 107 train loss: 0.56676328 epoch time: 30.51s step time: 0.0305s
# epoch: 108 train loss: 0.66195685 epoch time: 30.78s step time: 0.0308s
# epoch: 109 train loss: 0.58848387 epoch time: 30.56s step time: 0.0306s
# epoch: 110 train loss: 0.51255023 epoch time: 30.60s step time: 0.0306s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.060130368581973015
# =================================End Evaluation=================================
# predict total time: 17.945138454437256 s
# epoch: 111 train loss: 0.61814439 epoch time: 31.11s step time: 0.0311s
# epoch: 112 train loss: 0.60328650 epoch time: 30.53s step time: 0.0305s
# epoch: 113 train loss: 0.51519573 epoch time: 30.92s step time: 0.0309s
# epoch: 114 train loss: 0.58692473 epoch time: 30.89s step time: 0.0309s
# epoch: 115 train loss: 0.45317584 epoch time: 30.96s step time: 0.0310s
# epoch: 116 train loss: 0.57589608 epoch time: 30.58s step time: 0.0306s
# epoch: 117 train loss: 0.69355440 epoch time: 30.51s step time: 0.0305s
# epoch: 118 train loss: 0.47153223 epoch time: 30.40s step time: 0.0304s
# epoch: 119 train loss: 0.40927571 epoch time: 30.46s step time: 0.0305s
# epoch: 120 train loss: 0.57295668 epoch time: 30.44s step time: 0.0304s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.060408049400895836
# =================================End Evaluation=================================
# predict total time: 18.15675663948059 s
# epoch: 121 train loss: 0.59512609 epoch time: 30.80s step time: 0.0308s
# epoch: 122 train loss: 0.60564661 epoch time: 30.50s step time: 0.0305s
# epoch: 123 train loss: 0.67145407 epoch time: 30.39s step time: 0.0304s
# epoch: 124 train loss: 0.59278727 epoch time: 30.91s step time: 0.0309s
# epoch: 125 train loss: 0.51349878 epoch time: 31.01s step time: 0.0310s
# epoch: 126 train loss: 0.70951855 epoch time: 30.74s step time: 0.0307s
# epoch: 127 train loss: 0.76904750 epoch time: 30.59s step time: 0.0306s
# epoch: 128 train loss: 0.66214460 epoch time: 30.44s step time: 0.0304s
# epoch: 129 train loss: 0.52601755 epoch time: 30.58s step time: 0.0306s
# epoch: 130 train loss: 0.64446735 epoch time: 31.27s step time: 0.0313s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.05828356449585408
# =================================End Evaluation=================================
# predict total time: 17.901254653930664 s
# epoch: 131 train loss: 0.79148370 epoch time: 30.60s step time: 0.0306s
# epoch: 132 train loss: 0.58450687 epoch time: 31.07s step time: 0.0311s
# epoch: 133 train loss: 0.46207112 epoch time: 31.27s step time: 0.0313s
# epoch: 134 train loss: 0.65041542 epoch time: 30.71s step time: 0.0307s
# epoch: 135 train loss: 0.59474409 epoch time: 30.67s step time: 0.0307s
# epoch: 136 train loss: 0.69277716 epoch time: 30.58s step time: 0.0306s
# epoch: 137 train loss: 0.57890809 epoch time: 30.45s step time: 0.0304s
# epoch: 138 train loss: 0.61596543 epoch time: 30.93s step time: 0.0309s
# epoch: 139 train loss: 0.60948730 epoch time: 31.11s step time: 0.0311s
# epoch: 140 train loss: 0.58394039 epoch time: 30.68s step time: 0.0307s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.057051356196869164
# =================================End Evaluation=================================
# predict total time: 17.88123345375061 s
# epoch: 141 train loss: 0.60616392 epoch time: 30.86s step time: 0.0309s
# epoch: 142 train loss: 0.54683173 epoch time: 31.72s step time: 0.0317s
# epoch: 143 train loss: 0.55527675 epoch time: 30.58s step time: 0.0306s
# epoch: 144 train loss: 0.53893620 epoch time: 30.55s step time: 0.0306s
# epoch: 145 train loss: 0.46591306 epoch time: 30.68s step time: 0.0307s
# epoch: 146 train loss: 0.72070628 epoch time: 30.91s step time: 0.0309s
# epoch: 147 train loss: 0.72032672 epoch time: 31.03s step time: 0.0310s
# epoch: 148 train loss: 0.59482175 epoch time: 31.23s step time: 0.0312s
# epoch: 149 train loss: 0.55644649 epoch time: 31.31s step time: 0.0313s
# epoch: 150 train loss: 0.68139791 epoch time: 31.02s step time: 0.0310s
# ================================Start Evaluation================================
# mean rel_rmse_error: 0.05586790869757533
# =================================End Evaluation=================================
# predict total time: 18.196137189865112 s

# %%
visual(model, test_input, labels_unif, data_params)
# Out:
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.

# %%
with open('images/result.gif', 'rb') as f:
    display(Image(data=f.read(), format='png', embed=True))
