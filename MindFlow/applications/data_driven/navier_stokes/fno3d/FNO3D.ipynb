# %% [markdown]
# # Solve Navier-Stokes equation based on Fourier Neural Operator
#
# [![DownloadNotebook](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_notebook_en.png)](https://obs.dualstack.cn-north-4.myhuaweicloud.com/mindspore-website/notebook/master/mindflow/en/data_driven/mindspore_navier_stokes_FNO2D.ipynb) [![DownloadCode](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_download_code_en.png)](https://obs.dualstack.cn-north-4.myhuaweicloud.com/mindspore-website/notebook/master/mindflow/en/data_driven/mindspore_navier_stokes_FNO2D.py) [![ViewSource](https://mindspore-website.obs.cn-north-4.myhuaweicloud.com/website-images/master/resource/_static/logo_source_en.png)](https://gitee.com/mindspore/docs/blob/master/docs/mindflow/docs/source_en/data_driven/navier_stokes_FNO2D.ipynb)

# %% [markdown]
# ## Overview
#
# Computational fluid dynamics is one of the most important techniques in the field of fluid mechanics in the 21st century. The flow analysis, prediction and control can be realized by solving the governing equations of fluid mechanics by numerical method. Traditional finite element method (FEM) and finite difference method (FDM) are inefficient because of the complex simulation process (physical modeling, meshing, numerical discretization, iterative solution, etc.) and high computing costs. Therefore, it is necessary to improve the efficiency of fluid simulation with AI.
#
# Machine learning methods provide a new paradigm for scientific computing by providing a fast solver similar to traditional methods. Classical neural networks learn mappings between finite dimensional spaces and can only learn solutions related to specific discretizations. Different from traditional neural networks, Fourier Neural Operator (FNO) is a new deep learning architecture that can learn mappings between infinite-dimensional function spaces. It directly learns mappings from arbitrary function parameters to solutions to solve a class of partial differential equations. Therefore, it has a stronger generalization capability. More information can be found in the paper, [Fourier Neural Operator for Parametric Partial Differential Equations](https://arxiv.org/abs/2010.08895).
#
# This tutorial describes how to solve the Navier-Stokes equation using 3-d Fourier neural operator.

# %% [markdown]
# ## Navier-Stokes equation
#
# Navier-Stokes equation is a classical equation in computational fluid dynamics. It is a set of partial differential equations describing the conservation of fluid momentum, called N-S equation for short. Its vorticity form in two-dimensional incompressible flows is as follows:
#
# $$ \partial_t w(x, t)+u(x, t) \cdot \nabla w(x, t)=\nu \Delta w(x, t)+f(x), \quad x \in(0,1)^2, t \in(0, T] $$
#
# $$ \nabla \cdot u(x, t)=0, \quad x \in(0,1)^2, t \in[0, T] $$
#
# $$ w(x, 0)=w_0(x), \quad x \in(0,1)^2 $$
#
# where $u$ is the velocity field, $w=\nabla \times u$ is the vorticity, $w_0(x)$ is the initial vorticity, $\nu$ is the viscosity coefficient, $f(x)$ is the forcing function.

# %% [markdown]
# ## Problem Description
#
# We aim to solve two-dimensional incompressible N-S equation by learning the operator mapping from each time step to the next time step:
#
# $$ w_t \mapsto w(\cdot, t+1) $$

# %% [markdown]
# ## Technology Path
#
# MindFlow solves the problem as follows:
#
# 1. Training Dataset Construction.
# 2. Model Construction.
# 3. Optimizer and Loss Function.
# 4. Model Training.

# %% [markdown]
# ## Fourier Neural Operator
#
# The following figure shows the architecture of the Fourier Neural Operator model. In the figure, $w_0(x)$ represents the initial vorticity. The input vector is lifted to higher dimension channel space by the lifting layer. Then the mapping result is used as the input of the Fourier layer to perform nonlinear transformation of the frequency domain information. Finally, the decoding layer maps the transformation result to the final prediction result $w_1(x)$.
#
# The Fourier Neural Operator consists of the lifting Layer, Fourier Layers, and the decoding Layer.
#
# ![Fourier Neural Operator model structure](images/FNO.png)
#
# Fourier layers: Start from input V. On top: apply the Fourier transform $\mathcal{F}$; a linear transform R on the lower Fourier modes and filters out the higher modes; then apply the inverse Fourier transform $\mathcal{F}^{-1}$. On the bottom: apply a local linear transform W. Finally, the Fourier Layer output vector is obtained through the activation function.
#
# ![Fourier Layer structure](images/FNO-2.png)

# %%
#add search path
import sys
import os
project_root = os.path.abspath("../../../../..")
sys.path.append(project_root)

# %%
import os
import time
import numpy as np

from mindspore import nn, ops, jit, data_sink, save_checkpoint, context, Tensor, ops
from mindspore.common import set_seed
from mindspore import dtype as mstype
# Out:
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %% [markdown]
# The following `src` pacakage can be downloaded in [applications/data_driven/navier_stokes/fno3d/src](https://gitee.com/mindspore/mindscience/tree/master/MindFlow/applications/data_driven/navier_stokes/fno3d/src).

# %%
from mindscience.common import get_warmup_cosine_annealing_lr
from mindscience.utils import load_yaml_config
from mindscience.models import FNO3D

from src import LpLoss, UnitGaussianNormalizer, create_training_dataset

set_seed(0)
np.random.seed(0)

# %%
# set context for training: using graph mode for high performance training with GPU acceleration
context.set_context(mode=context.GRAPH_MODE, device_target='Ascend', device_id=1,max_device_memory="32GB")
use_ascend = context.get_context(attr_key='device_target') == "Ascend"
config = load_yaml_config('./configs/fno3d.yaml')
data_params = config["data"]
model_params = config["model"]
optimizer_params = config["optimizer"]
summary_params = config["summary"]

sub = data_params["sub"]
grid_size = model_params["input_resolution"] // sub
input_timestep = model_params["input_timestep"]
output_timestep = model_params["output_timestep"]

# %% [markdown]
# ## Training Dataset Construction
#
# Download the training and test dataset: [data_driven/navier_stokes_3d](https://download-mindspore.osinfra.cn/mindscience/mindflow/dataset/applications/data_driven/navier_stokes_3d/) .
#
# In this case, training data sets and test data sets are generated according to Zongyi Li's data set in [Fourier Neural Operator for Parametric Partial Differential Equations](https://arxiv.org/pdf/2010.08895.pdf) . The settings are as follows:
#
# The initial condition $w_0(x)$ is generated according to periodic boundary conditions:
#
# $$ w_0 \sim \mu, \mu=\mathcal{N}\left(0,7^{3 / 2}(-\Delta+49 I)^{-2.5}\right) $$
#
# The forcing function is defined as:
#
# $$ f(x)=0.1\left(\sin \left(2 \pi\left(x_1+x_2\right)\right)+\right.\cos(2 \pi(x_1+x_2))) $$
#
# We use a time-step of 1e-4 for the Crank–Nicolson scheme in the data-generated process where we record the solution every t = 1 time units. All data are generated on a 256 × 256 grid and are downsampled to 64 × 64\. In this case, the viscosity coefficient $\nu=1e-3$, the number of samples in the training set is 1000, and the number of samples in the test set is 200.

# %%
train_a = Tensor(np.load(os.path.join(
    data_params["root_dir"], "train_a.npy")), mstype.float32)
train_u = Tensor(np.load(os.path.join(
    data_params["root_dir"], "train_u.npy")), mstype.float32)
test_a = Tensor(np.load(os.path.join(
    data_params["root_dir"], "test_a.npy")), mstype.float32)
test_u = Tensor(np.load(os.path.join(
    data_params["root_dir"], "test_u.npy")), mstype.float32)
train_loader = create_training_dataset(data_params,
                                       shuffle=True)
steps_per_epoch = train_loader.get_dataset_size()

# %% [markdown]
# ## Model Construction
#
# The network is composed of 1 lifting layer, multiple Fourier layers and 1 decoding layer:
#
# - The Lifting layer corresponds to the `FNO3D.fc0` in the case, and maps the output data $x$ to the high dimension;
#
# - Multi-layer Fourier Layer corresponds to the `FNO3D.fno_seq` in the case. Discrete Fourier transform is used to realize the conversion between time domain and frequency domain;
#
# - The Decoding layer corresponds to `FNO3D.fc1` and `FNO3D.fc2` in the case to obtain the final predictive value.

# %%
if use_ascend:
    compute_type = mstype.float16
else:
    compute_type = mstype.float32
# prepare model
model = FNO3D(in_channels=model_params["in_channels"],
              out_channels=model_params["out_channels"],
              n_modes=model_params["modes"],
              resolutions=[model_params["input_resolution"],
                           model_params["input_resolution"], output_timestep],
              hidden_channels=model_params["width"],
              n_layers=model_params["depth"],
              projection_channels=4*model_params["width"],
              fno_compute_dtype=compute_type
              )

model_params_list = []
for k, v in model_params.items():
    model_params_list.append(f"{k}-{v}")
model_name = "_".join(model_params_list)

# %% [markdown]
# ## Optimizer and Loss Function
#
# Use the relative root mean square error as the loss function for network training:

# %%
lr = get_warmup_cosine_annealing_lr(lr_init=optimizer_params["learning_rate"],
                                    last_epoch=optimizer_params["epochs"],
                                    steps_per_epoch=steps_per_epoch,
                                    warmup_epochs=optimizer_params["warmup_epochs"])
optimizer = nn.optim.Adam(model.trainable_params(),
                          learning_rate=Tensor(lr), weight_decay=optimizer_params['weight_decay'])
loss_fn = LpLoss()
a_normalizer = UnitGaussianNormalizer(train_a)
y_normalizer = UnitGaussianNormalizer(train_u)

# %%
def calculate_l2_error(model, inputs, labels):
    """
    Evaluate the model respect to input data and label.
    Args:
        model (Cell): list of expressions node can by identified by mindspore.
        inputs (Tensor): the input data of network.
        labels (Tensor): the true output value of given inputs.
    """
    print("================================Start Evaluation================================")
    time_beg = time.time()
    rms_error = 0.0
    for i in range(labels.shape[0]):
        label = labels[i:i + 1]
        test_batch = inputs[i:i + 1]
        test_batch = a_normalizer.encode(test_batch)
        label = y_normalizer.encode(label)
        # test_batch = test_batch.reshape(
        #     1, grid_size, grid_size, 1, input_timestep).repeat(output_timestep, axis=3)
        test_batch = test_batch.reshape(
            1, grid_size, grid_size, 1, input_timestep).repeat(1, 1, 1, output_timestep, 1)
        prediction = model(test_batch).reshape(
            1, grid_size, grid_size, output_timestep)
        prediction = y_normalizer.decode(prediction)
        label = y_normalizer.decode(label)
        rms_error_step = loss_fn(prediction.reshape(
            1, -1), label.reshape(1, -1))
        rms_error += rms_error_step

    rms_error = rms_error / labels.shape[0]
    print(f"mean rms_error:{rms_error.asnumpy():.3f}")
    print(f"predict total time: {time.time() - time_beg:.2f} s")
    print("=================================End Evaluation=================================")

# %% [markdown]
# ## Training Function
#
# With MindSpore>= 2.0.0, you can train neural networks using functional programming paradigms, and single-step training functions are decorated with jit. The data_sink function is used to transfer the step-by-step training function and training dataset.

# %%
def forward_fn(data, label):
    bs = data.shape[0]
    data = a_normalizer.encode(data)
    label = y_normalizer.encode(label)
    # data = data.reshape(bs, grid_size, grid_size, 1, input_timestep).repeat(
    #     output_timestep, axis=3)
    data = data.reshape(bs, grid_size, grid_size, 1, input_timestep).repeat(
        1, 1, 1, output_timestep, 1)
    logits = model(data).reshape(bs, grid_size, grid_size, output_timestep)
    logits = y_normalizer.decode(logits)
    label = y_normalizer.decode(label)
    loss = loss_fn(logits.reshape(bs, -1), label.reshape(bs, -1))
    return loss


grad_fn = ops.value_and_grad(
    forward_fn, None, optimizer.parameters, has_aux=False)


@jit
def train_step(data, label):
    loss, grads = grad_fn(data, label)
    loss = ops.depend(loss, optimizer(grads))
    return loss


sink_process = data_sink(train_step, train_loader, sink_size=100)

# %% [markdown]
# ## Model Training
#
# With **MindSpore version >= 2.0.0**, we can use the functional programming for training neural networks.

# %%
def train():
    summary_dir = os.path.join("./summary1", model_name)
    ckpt_dir = os.path.join(summary_dir, "ckpt")
    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)
    model.set_train()
    for step in range(1, 1 + optimizer_params["epochs"]):
        local_time_beg = time.time()
        cur_loss = sink_process()
        print(
            f"epoch: {step} train loss: {cur_loss.asnumpy():.3f} epoch time: {time.time() - local_time_beg:.2f}s")
        if step % 10 == 0:
            print(f"loss: {cur_loss.asnumpy():.3f}")
            print(f"step: {step}, time elapsed: {(time.time() - local_time_beg) * 1000:.3f} ms")
            calculate_l2_error(model, test_a, test_u)
            save_checkpoint(model, os.path.join(
                ckpt_dir, model_params["name"]))

# %%
train()
# Out:
# [ERROR] CORE(21606,ffff9c057020,python):2025-12-01-17:38:38.588.442 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_21606/85871067.py]
# [ERROR] CORE(21606,ffff9c057020,python):2025-12-01-17:38:38.588.548 [mindspore/core/utils/file_utils.cc:253] GetRealPath] Get realpath failed, path[/tmp/ipykernel_21606/85871067.py]
# ...epoch: 1 train loss: 0.219 epoch time: 47.94s
# epoch: 2 train loss: 0.128 epoch time: 15.52s
# epoch: 3 train loss: 0.134 epoch time: 15.51s
# epoch: 4 train loss: 0.121 epoch time: 15.51s
# epoch: 5 train loss: 0.097 epoch time: 15.52s
# epoch: 6 train loss: 0.088 epoch time: 15.52s
# epoch: 7 train loss: 0.092 epoch time: 15.51s
# epoch: 8 train loss: 0.073 epoch time: 15.52s
# epoch: 9 train loss: 0.086 epoch time: 15.52s
# epoch: 10 train loss: 0.070 epoch time: 15.52s
# loss: 0.070
# step: 10, time elapsed: 15515.957 ms
# ================================Start Evaluation================================
# .mean rms_error:0.073
# predict total time: 13.89 s
# =================================End Evaluation=================================
# epoch: 11 train loss: 0.087 epoch time: 15.57s
# epoch: 12 train loss: 0.062 epoch time: 15.57s
# epoch: 13 train loss: 0.087 epoch time: 15.57s
# epoch: 14 train loss: 0.065 epoch time: 15.57s
# epoch: 15 train loss: 0.072 epoch time: 15.57s
# epoch: 16 train loss: 0.072 epoch time: 15.57s
# epoch: 17 train loss: 0.080 epoch time: 15.57s
# epoch: 18 train loss: 0.061 epoch time: 15.57s
# epoch: 19 train loss: 0.074 epoch time: 15.57s
# epoch: 20 train loss: 0.066 epoch time: 15.56s
# loss: 0.066
# step: 20, time elapsed: 15563.825 ms
# ================================Start Evaluation================================
# mean rms_error:0.059
# predict total time: 5.60 s
# =================================End Evaluation=================================
# epoch: 21 train loss: 0.060 epoch time: 15.57s
# epoch: 22 train loss: 0.082 epoch time: 15.57s
# epoch: 23 train loss: 0.070 epoch time: 15.57s
# epoch: 24 train loss: 0.061 epoch time: 15.57s
# epoch: 25 train loss: 0.058 epoch time: 15.58s
# epoch: 26 train loss: 0.075 epoch time: 15.57s
# epoch: 27 train loss: 0.057 epoch time: 15.59s
# epoch: 28 train loss: 0.056 epoch time: 15.61s
# epoch: 29 train loss: 0.061 epoch time: 15.57s
# epoch: 30 train loss: 0.055 epoch time: 15.56s
# loss: 0.055
# step: 30, time elapsed: 15559.070 ms
# ================================Start Evaluation================================
# mean rms_error:0.056
# predict total time: 5.85 s
# =================================End Evaluation=================================
# epoch: 31 train loss: 0.049 epoch time: 15.59s
# epoch: 32 train loss: 0.053 epoch time: 15.56s
# epoch: 33 train loss: 0.045 epoch time: 15.59s
# epoch: 34 train loss: 0.061 epoch time: 15.57s
# epoch: 35 train loss: 0.042 epoch time: 15.56s
# epoch: 36 train loss: 0.049 epoch time: 15.57s
# epoch: 37 train loss: 0.052 epoch time: 15.57s
# epoch: 38 train loss: 0.053 epoch time: 15.57s
# epoch: 39 train loss: 0.062 epoch time: 15.57s
# epoch: 40 train loss: 0.063 epoch time: 15.59s
# loss: 0.063
# step: 40, time elapsed: 15586.997 ms
# ================================Start Evaluation================================
# mean rms_error:0.054
# predict total time: 5.70 s
# =================================End Evaluation=================================
# epoch: 41 train loss: 0.055 epoch time: 15.56s
# epoch: 42 train loss: 0.050 epoch time: 15.57s
# epoch: 43 train loss: 0.065 epoch time: 15.57s
# epoch: 44 train loss: 0.044 epoch time: 15.57s
# epoch: 45 train loss: 0.062 epoch time: 15.57s
# epoch: 46 train loss: 0.048 epoch time: 15.57s
# epoch: 47 train loss: 0.047 epoch time: 15.57s
# epoch: 48 train loss: 0.048 epoch time: 15.57s
# epoch: 49 train loss: 0.046 epoch time: 15.57s
# epoch: 50 train loss: 0.059 epoch time: 15.56s
# loss: 0.059
# step: 50, time elapsed: 15559.342 ms
# ================================Start Evaluation================================
# mean rms_error:0.062
# predict total time: 5.95 s
# =================================End Evaluation=================================
# epoch: 51 train loss: 0.049 epoch time: 15.57s
# epoch: 52 train loss: 0.051 epoch time: 15.57s
# epoch: 53 train loss: 0.046 epoch time: 15.59s
# epoch: 54 train loss: 0.057 epoch time: 15.57s
# epoch: 55 train loss: 0.050 epoch time: 15.57s
# epoch: 56 train loss: 0.042 epoch time: 15.57s
# epoch: 57 train loss: 0.046 epoch time: 15.56s
# epoch: 58 train loss: 0.052 epoch time: 15.57s
# epoch: 59 train loss: 0.048 epoch time: 15.57s
# epoch: 60 train loss: 0.044 epoch time: 15.57s
# loss: 0.044
# step: 60, time elapsed: 15573.652 ms
# ================================Start Evaluation================================
# mean rms_error:0.042
# predict total time: 5.73 s
# =================================End Evaluation=================================
# epoch: 61 train loss: 0.043 epoch time: 15.57s
# epoch: 62 train loss: 0.064 epoch time: 15.58s
# epoch: 63 train loss: 0.043 epoch time: 15.57s
# epoch: 64 train loss: 0.042 epoch time: 15.56s
# epoch: 65 train loss: 0.038 epoch time: 15.57s
# epoch: 66 train loss: 0.037 epoch time: 15.56s
# epoch: 67 train loss: 0.042 epoch time: 15.58s
# epoch: 68 train loss: 0.047 epoch time: 15.56s
# epoch: 69 train loss: 0.038 epoch time: 15.58s
# epoch: 70 train loss: 0.030 epoch time: 15.56s
# loss: 0.030
# step: 70, time elapsed: 15558.140 ms
# ================================Start Evaluation================================
# mean rms_error:0.036
# predict total time: 5.74 s
# =================================End Evaluation=================================
# epoch: 71 train loss: 0.039 epoch time: 15.56s
# epoch: 72 train loss: 0.040 epoch time: 15.57s
# epoch: 73 train loss: 0.053 epoch time: 15.56s
# epoch: 74 train loss: 0.037 epoch time: 15.56s
# epoch: 75 train loss: 0.032 epoch time: 15.57s
# epoch: 76 train loss: 0.033 epoch time: 15.57s
# epoch: 77 train loss: 0.040 epoch time: 15.56s
# epoch: 78 train loss: 0.037 epoch time: 15.57s
# epoch: 79 train loss: 0.034 epoch time: 15.55s
# epoch: 80 train loss: 0.034 epoch time: 15.58s
# loss: 0.034
# step: 80, time elapsed: 15575.841 ms
# ================================Start Evaluation================================
# mean rms_error:0.037
# predict total time: 5.73 s
# =================================End Evaluation=================================
# epoch: 81 train loss: 0.034 epoch time: 15.56s
# epoch: 82 train loss: 0.031 epoch time: 15.57s
# epoch: 83 train loss: 0.033 epoch time: 15.56s
# epoch: 84 train loss: 0.035 epoch time: 15.60s
# epoch: 85 train loss: 0.030 epoch time: 15.57s
# epoch: 86 train loss: 0.030 epoch time: 15.57s
# epoch: 87 train loss: 0.035 epoch time: 15.56s
# epoch: 88 train loss: 0.033 epoch time: 15.56s
# epoch: 89 train loss: 0.034 epoch time: 15.57s
# epoch: 90 train loss: 0.037 epoch time: 15.56s
# loss: 0.037
# step: 90, time elapsed: 15556.851 ms
# ================================Start Evaluation================================
# mean rms_error:0.036
# predict total time: 6.01 s
# =================================End Evaluation=================================
# epoch: 91 train loss: 0.032 epoch time: 15.55s
# epoch: 92 train loss: 0.031 epoch time: 15.58s
# epoch: 93 train loss: 0.024 epoch time: 15.57s
# epoch: 94 train loss: 0.026 epoch time: 15.57s
# epoch: 95 train loss: 0.031 epoch time: 15.57s
# epoch: 96 train loss: 0.035 epoch time: 15.56s
# epoch: 97 train loss: 0.027 epoch time: 15.56s
# epoch: 98 train loss: 0.031 epoch time: 15.57s
# epoch: 99 train loss: 0.026 epoch time: 15.57s
# epoch: 100 train loss: 0.025 epoch time: 15.56s
# loss: 0.025
# step: 100, time elapsed: 15559.764 ms
# ================================Start Evaluation================================
# mean rms_error:0.029
# predict total time: 5.58 s
# =================================End Evaluation=================================
# epoch: 101 train loss: 0.030 epoch time: 15.56s
# epoch: 102 train loss: 0.026 epoch time: 15.57s
# epoch: 103 train loss: 0.028 epoch time: 15.57s
# epoch: 104 train loss: 0.027 epoch time: 15.57s
# epoch: 105 train loss: 0.032 epoch time: 15.57s
# epoch: 106 train loss: 0.029 epoch time: 15.57s
# epoch: 107 train loss: 0.024 epoch time: 15.58s
# epoch: 108 train loss: 0.027 epoch time: 15.57s
# epoch: 109 train loss: 0.022 epoch time: 15.58s
# epoch: 110 train loss: 0.021 epoch time: 15.57s
# loss: 0.021
# step: 110, time elapsed: 15571.548 ms
# ================================Start Evaluation================================
# mean rms_error:0.025
# predict total time: 5.72 s
# =================================End Evaluation=================================
# epoch: 111 train loss: 0.037 epoch time: 15.56s
# epoch: 112 train loss: 0.033 epoch time: 15.56s
# epoch: 113 train loss: 0.025 epoch time: 15.58s
# epoch: 114 train loss: 0.020 epoch time: 15.56s
# epoch: 115 train loss: 0.020 epoch time: 15.58s
# epoch: 116 train loss: 0.020 epoch time: 15.56s
# epoch: 117 train loss: 0.026 epoch time: 15.56s
# epoch: 118 train loss: 0.020 epoch time: 15.57s
# epoch: 119 train loss: 0.021 epoch time: 15.56s
# epoch: 120 train loss: 0.021 epoch time: 15.58s
# loss: 0.021
# step: 120, time elapsed: 15582.875 ms
# ================================Start Evaluation================================
# mean rms_error:0.024
# predict total time: 5.78 s
# =================================End Evaluation=================================
# epoch: 121 train loss: 0.023 epoch time: 15.56s
# epoch: 122 train loss: 0.017 epoch time: 15.56s
# epoch: 123 train loss: 0.019 epoch time: 15.57s
# epoch: 124 train loss: 0.018 epoch time: 15.56s
# epoch: 125 train loss: 0.028 epoch time: 15.56s
# epoch: 126 train loss: 0.019 epoch time: 15.56s
# epoch: 127 train loss: 0.018 epoch time: 15.57s
# epoch: 128 train loss: 0.020 epoch time: 15.56s
# epoch: 129 train loss: 0.017 epoch time: 15.56s
# epoch: 130 train loss: 0.017 epoch time: 15.57s
# loss: 0.017
# step: 130, time elapsed: 15567.258 ms
# ================================Start Evaluation================================
# mean rms_error:0.020
# predict total time: 5.56 s
# =================================End Evaluation=================================
# epoch: 131 train loss: 0.018 epoch time: 15.54s
# epoch: 132 train loss: 0.019 epoch time: 15.55s
# epoch: 133 train loss: 0.016 epoch time: 15.57s
# epoch: 134 train loss: 0.018 epoch time: 15.56s
# epoch: 135 train loss: 0.015 epoch time: 15.56s
# epoch: 136 train loss: 0.017 epoch time: 15.55s
# epoch: 137 train loss: 0.014 epoch time: 15.57s
# epoch: 138 train loss: 0.018 epoch time: 15.58s
# epoch: 139 train loss: 0.013 epoch time: 15.56s
# epoch: 140 train loss: 0.014 epoch time: 15.56s
# loss: 0.014
# step: 140, time elapsed: 15564.406 ms
# ================================Start Evaluation================================
# mean rms_error:0.018
# predict total time: 5.58 s
# =================================End Evaluation=================================
# epoch: 141 train loss: 0.016 epoch time: 15.55s
# epoch: 142 train loss: 0.013 epoch time: 15.55s
# epoch: 143 train loss: 0.023 epoch time: 15.55s
# epoch: 144 train loss: 0.016 epoch time: 15.55s
# epoch: 145 train loss: 0.016 epoch time: 15.57s
# epoch: 146 train loss: 0.014 epoch time: 15.57s
# epoch: 147 train loss: 0.015 epoch time: 15.56s
# epoch: 148 train loss: 0.012 epoch time: 15.56s
# epoch: 149 train loss: 0.018 epoch time: 15.55s
# epoch: 150 train loss: 0.014 epoch time: 15.56s
# loss: 0.014
# step: 150, time elapsed: 15561.411 ms
# ================================Start Evaluation================================
# mean rms_error:0.018
# predict total time: 5.61 s
# =================================End Evaluation=================================
